# %% [markdown]
# ## **Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ**

# %% [markdown]
# # Путешествие по Спрингфилду.
#
#
# Сегодня вам предстоить помочь телекомпании FOX  в обработке их контента. Как вы знаете сериал Симсоны идет на телеэкранах более 25 лет и за это время скопилось очень много видео материала. Персоонажи менялись вместе с изменяющимися графическими технологиями   и Гомер 2018 не очень похож на Гомера 1989. Нашей задачей будет научиться классифицировать персонажей проживающих в Спрингфилде. Думаю, что нет смысла представлять каждого из них в отдельности.
#
#
#
#  ![alt text](https://vignette.wikia.nocookie.net/simpsons/images/5/5a/Spider_fat_piglet.png/revision/latest/scale-to-width-down/640?cb=20111118140828)

# %% [markdown]
# ### Установка зависимостей

# %%
# we will verify that GPU is enabled for this notebook
# following should print: CUDA is available!  Training on GPU ...
# 
# if it prints otherwise, then you need to enable GPU: 
# from Menu > Runtime > Change Runtime Type > Hardware Accelerator > GPU

import torch
import numpy as np

train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
# !nvidia-smi
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# В нашем тесте будет 990 картнок, для которых вам будет необходимо предсказать класс.

# %%
import pickle
import numpy as np
from skimage import io

from tqdm import tqdm, tqdm_notebook
from PIL import Image
from pathlib import Path

from torchvision import transforms
from multiprocessing.pool import ThreadPool
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

from matplotlib import colors, pyplot as plt
# %matplotlib inline

# в sklearn не все гладко, чтобы в colab удобно выводить картинки 
# мы будем игнорировать warnings
import warnings
warnings.filterwarnings(action='ignore', category=DeprecationWarning)

# %%
# разные режимы датасета 
DATA_MODES = ['train', 'val', 'test']
# все изображения будут масштабированы к размеру 224x224 px
RESCALE_SIZE = 224
# работаем на видеокарте
DEVICE = torch.device("cuda")

# %% [markdown]
# https://jhui.github.io/2018/02/09/PyTorch-Data-loading-preprocess_torchvision/

# %% [markdown]
# Ниже мы исспользуем враппер над датасетом для удобной работы. Вам стоит понимать, что происходит с LabelEncoder и  с torch.Transformation.
#
# ToTensor конвертирует  PIL Image с параметрами в диапазоне [0, 255] (как все пиксели) в FloatTensor размера (C x H x W) [0,1] , затем производится масштабирование:
# $input = \frac{input - \mu}{\text{standard deviation}} $, <br>       константы - средние и дисперсии по каналам на основе ImageNet
#
#
# Стоит также отметить, что мы переопределяем метод __getitem__ для удобства работы с данной структурой данных.
#  Также используется LabelEncoder для преобразования строковых меток классов в id и обратно. В описании датасета указано, что картинки разного размера, так как брались напрямую с видео, поэтому следуем привести их к одному размер (это делает метод  _prepare_sample)

# %%
class SimpsonsDataset(Dataset):
    """
    Датасет с картинками, который паралельно подгружает их из папок
    производит скалирование и превращение в торчевые тензоры
    """
    def __init__(self, files, mode):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files)
        # режим работы
        self.mode = mode

        if self.mode not in DATA_MODES:
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.len_ = len(self.files)
     
        self.label_encoder = LabelEncoder()

        if self.mode != 'test':
            self.labels = [path.parent.name for path in self.files]
            self.label_encoder.fit(self.labels)

            with open('label_encoder.pkl', 'wb') as le_dump_file:
                  pickle.dump(self.label_encoder, le_dump_file)
                      
    def __len__(self):
        return self.len_
      
    def load_sample(self, file):
        image = Image.open(file)
        image.load()
        return image
  
    def __getitem__(self, index):
        # для преобразования изображений в тензоры PyTorch и нормализации входа
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
        ])
        x = self.load_sample(self.files[index])
        x = self._prepare_sample(x)
        x = np.array(x / 255, dtype='float32')
        x = transform(x)
        if self.mode == 'test':
            return x
        else:
            label = self.labels[index]
            label_id = self.label_encoder.transform([label])
            y = label_id.item()
            return x, y
        
    def _prepare_sample(self, image):
        image = image.resize((RESCALE_SIZE, RESCALE_SIZE))
        return np.array(image)

# %%
def imshow(inp, title=None, plt_ax=plt, default=False):
    """Imshow для тензоров"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt_ax.imshow(inp)
    if title is not None:
        plt_ax.set_title(title)
    plt_ax.grid(False)

# %%
TRAIN_DIR = Path('train/simpsons_dataset')
TEST_DIR = Path('testset/testset')

train_val_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))

# %%
test_files
# Out:
# [WindowsPath('testset/testset/img0.jpg'),
#  WindowsPath('testset/testset/img1.jpg'),
#  WindowsPath('testset/testset/img10.jpg'),
#  WindowsPath('testset/testset/img100.jpg'),
#  WindowsPath('testset/testset/img101.jpg'),
#  WindowsPath('testset/testset/img102.jpg'),
#  WindowsPath('testset/testset/img103.jpg'),
#  WindowsPath('testset/testset/img104.jpg'),
#  WindowsPath('testset/testset/img105.jpg'),
#  WindowsPath('testset/testset/img106.jpg'),
#  WindowsPath('testset/testset/img107.jpg'),
#  WindowsPath('testset/testset/img108.jpg'),
#  WindowsPath('testset/testset/img109.jpg'),
#  WindowsPath('testset/testset/img11.jpg'),
#  WindowsPath('testset/testset/img110.jpg'),
#  WindowsPath('testset/testset/img111.jpg'),
#  WindowsPath('testset/testset/img112.jpg'),
#  WindowsPath('testset/testset/img113.jpg'),
#  WindowsPath('testset/testset/img114.jpg'),
#  WindowsPath('testset/testset/img115.jpg'),
#  WindowsPath('testset/testset/img116.jpg'),
#  WindowsPath('testset/testset/img117.jpg'),
#  WindowsPath('testset/testset/img118.jpg'),
#  WindowsPath('testset/testset/img119.jpg'),
#  WindowsPath('testset/testset/img12.jpg'),
#  WindowsPath('testset/testset/img120.jpg'),
#  WindowsPath('testset/testset/img121.jpg'),
#  WindowsPath('testset/testset/img122.jpg'),
#  WindowsPath('testset/testset/img123.jpg'),
#  WindowsPath('testset/testset/img124.jpg'),
#  WindowsPath('testset/testset/img125.jpg'),
#  WindowsPath('testset/testset/img126.jpg'),
#  WindowsPath('testset/testset/img127.jpg'),
#  WindowsPath('testset/testset/img128.jpg'),
#  WindowsPath('testset/testset/img129.jpg'),
#  WindowsPath('testset/testset/img13.jpg'),
#  WindowsPath('testset/testset/img130.jpg'),
#  WindowsPath('testset/testset/img131.jpg'),
#  WindowsPath('testset/testset/img132.jpg'),
#  WindowsPath('testset/testset/img133.jpg'),
#  WindowsPath('testset/testset/img134.jpg'),
#  WindowsPath('testset/testset/img135.jpg'),
#  WindowsPath('testset/testset/img136.jpg'),
#  WindowsPath('testset/testset/img137.jpg'),
#  WindowsPath('testset/testset/img138.jpg'),
#  WindowsPath('testset/testset/img139.jpg'),
#  WindowsPath('testset/testset/img14.jpg'),
#  WindowsPath('testset/testset/img140.jpg'),
#  WindowsPath('testset/testset/img141.jpg'),
#  WindowsPath('testset/testset/img142.jpg'),
#  WindowsPath('testset/testset/img143.jpg'),
#  WindowsPath('testset/testset/img144.jpg'),
#  WindowsPath('testset/testset/img145.jpg'),
#  WindowsPath('testset/testset/img146.jpg'),
#  WindowsPath('testset/testset/img147.jpg'),
#  WindowsPath('testset/testset/img148.jpg'),
#  WindowsPath('testset/testset/img149.jpg'),
#  WindowsPath('testset/testset/img15.jpg'),
#  WindowsPath('testset/testset/img150.jpg'),
#  WindowsPath('testset/testset/img151.jpg'),
#  WindowsPath('testset/testset/img152.jpg'),
#  WindowsPath('testset/testset/img153.jpg'),
#  WindowsPath('testset/testset/img154.jpg'),
#  WindowsPath('testset/testset/img155.jpg'),
#  WindowsPath('testset/testset/img156.jpg'),
#  WindowsPath('testset/testset/img157.jpg'),
#  WindowsPath('testset/testset/img158.jpg'),
#  WindowsPath('testset/testset/img159.jpg'),
#  WindowsPath('testset/testset/img16.jpg'),
#  WindowsPath('testset/testset/img160.jpg'),
#  WindowsPath('testset/testset/img161.jpg'),
#  WindowsPath('testset/testset/img162.jpg'),
#  WindowsPath('testset/testset/img163.jpg'),
#  WindowsPath('testset/testset/img164.jpg'),
#  WindowsPath('testset/testset/img165.jpg'),
#  WindowsPath('testset/testset/img166.jpg'),
#  WindowsPath('testset/testset/img167.jpg'),
#  WindowsPath('testset/testset/img168.jpg'),
#  WindowsPath('testset/testset/img169.jpg'),
#  WindowsPath('testset/testset/img17.jpg'),
#  WindowsPath('testset/testset/img170.jpg'),
#  WindowsPath('testset/testset/img171.jpg'),
#  WindowsPath('testset/testset/img172.jpg'),
#  WindowsPath('testset/testset/img173.jpg'),
#  WindowsPath('testset/testset/img174.jpg'),
#  WindowsPath('testset/testset/img175.jpg'),
#  WindowsPath('testset/testset/img176.jpg'),
#  WindowsPath('testset/testset/img177.jpg'),
#  WindowsPath('testset/testset/img178.jpg'),
#  WindowsPath('testset/testset/img179.jpg'),
#  WindowsPath('testset/testset/img18.jpg'),
#  WindowsPath('testset/testset/img180.jpg'),
#  WindowsPath('testset/testset/img181.jpg'),
#  WindowsPath('testset/testset/img182.jpg'),
#  WindowsPath('testset/testset/img183.jpg'),
#  WindowsPath('testset/testset/img184.jpg'),
#  WindowsPath('testset/testset/img185.jpg'),
#  WindowsPath('testset/testset/img186.jpg'),
#  WindowsPath('testset/testset/img187.jpg'),
#  WindowsPath('testset/testset/img188.jpg'),
#  WindowsPath('testset/testset/img189.jpg'),
#  WindowsPath('testset/testset/img19.jpg'),
#  WindowsPath('testset/testset/img190.jpg'),
#  WindowsPath('testset/testset/img191.jpg'),
#  WindowsPath('testset/testset/img192.jpg'),
#  WindowsPath('testset/testset/img193.jpg'),
#  WindowsPath('testset/testset/img194.jpg'),
#  WindowsPath('testset/testset/img195.jpg'),
#  WindowsPath('testset/testset/img196.jpg'),
#  WindowsPath('testset/testset/img197.jpg'),
#  WindowsPath('testset/testset/img198.jpg'),
#  WindowsPath('testset/testset/img199.jpg'),
#  WindowsPath('testset/testset/img2.jpg'),
#  WindowsPath('testset/testset/img20.jpg'),
#  WindowsPath('testset/testset/img200.jpg'),
#  WindowsPath('testset/testset/img201.jpg'),
#  WindowsPath('testset/testset/img202.jpg'),
#  WindowsPath('testset/testset/img203.jpg'),
#  WindowsPath('testset/testset/img204.jpg'),
#  WindowsPath('testset/testset/img205.jpg'),
#  WindowsPath('testset/testset/img206.jpg'),
#  WindowsPath('testset/testset/img207.jpg'),
#  WindowsPath('testset/testset/img208.jpg'),
#  WindowsPath('testset/testset/img209.jpg'),
#  WindowsPath('testset/testset/img21.jpg'),
#  WindowsPath('testset/testset/img210.jpg'),
#  WindowsPath('testset/testset/img211.jpg'),
#  WindowsPath('testset/testset/img212.jpg'),
#  WindowsPath('testset/testset/img213.jpg'),
#  WindowsPath('testset/testset/img214.jpg'),
#  WindowsPath('testset/testset/img215.jpg'),
#  WindowsPath('testset/testset/img216.jpg'),
#  WindowsPath('testset/testset/img217.jpg'),
#  WindowsPath('testset/testset/img218.jpg'),
#  WindowsPath('testset/testset/img219.jpg'),
#  WindowsPath('testset/testset/img22.jpg'),
#  WindowsPath('testset/testset/img220.jpg'),
#  WindowsPath('testset/testset/img221.jpg'),
#  WindowsPath('testset/testset/img222.jpg'),
#  WindowsPath('testset/testset/img223.jpg'),
#  WindowsPath('testset/testset/img224.jpg'),
#  WindowsPath('testset/testset/img225.jpg'),
#  WindowsPath('testset/testset/img226.jpg'),
#  WindowsPath('testset/testset/img227.jpg'),
#  WindowsPath('testset/testset/img228.jpg'),
#  WindowsPath('testset/testset/img229.jpg'),
#  WindowsPath('testset/testset/img23.jpg'),
#  WindowsPath('testset/testset/img230.jpg'),
#  WindowsPath('testset/testset/img231.jpg'),
#  WindowsPath('testset/testset/img232.jpg'),
#  WindowsPath('testset/testset/img233.jpg'),
#  WindowsPath('testset/testset/img234.jpg'),
#  WindowsPath('testset/testset/img235.jpg'),
#  WindowsPath('testset/testset/img236.jpg'),
#  WindowsPath('testset/testset/img237.jpg'),
#  WindowsPath('testset/testset/img238.jpg'),
#  WindowsPath('testset/testset/img239.jpg'),
#  WindowsPath('testset/testset/img24.jpg'),
#  WindowsPath('testset/testset/img240.jpg'),
#  WindowsPath('testset/testset/img241.jpg'),
#  WindowsPath('testset/testset/img242.jpg'),
#  WindowsPath('testset/testset/img243.jpg'),
#  WindowsPath('testset/testset/img244.jpg'),
#  WindowsPath('testset/testset/img245.jpg'),
#  WindowsPath('testset/testset/img246.jpg'),
#  WindowsPath('testset/testset/img247.jpg'),
#  WindowsPath('testset/testset/img248.jpg'),
#  WindowsPath('testset/testset/img249.jpg'),
#  WindowsPath('testset/testset/img25.jpg'),
#  WindowsPath('testset/testset/img250.jpg'),
#  WindowsPath('testset/testset/img251.jpg'),
#  WindowsPath('testset/testset/img252.jpg'),
#  WindowsPath('testset/testset/img253.jpg'),
#  WindowsPath('testset/testset/img254.jpg'),
#  WindowsPath('testset/testset/img255.jpg'),
#  WindowsPath('testset/testset/img256.jpg'),
#  WindowsPath('testset/testset/img257.jpg'),
#  WindowsPath('testset/testset/img258.jpg'),
#  WindowsPath('testset/testset/img259.jpg'),
#  WindowsPath('testset/testset/img26.jpg'),
#  WindowsPath('testset/testset/img260.jpg'),
#  WindowsPath('testset/testset/img261.jpg'),
#  WindowsPath('testset/testset/img262.jpg'),
#  WindowsPath('testset/testset/img263.jpg'),
#  WindowsPath('testset/testset/img264.jpg'),
#  WindowsPath('testset/testset/img265.jpg'),
#  WindowsPath('testset/testset/img266.jpg'),
#  WindowsPath('testset/testset/img267.jpg'),
#  WindowsPath('testset/testset/img268.jpg'),
#  WindowsPath('testset/testset/img269.jpg'),
#  WindowsPath('testset/testset/img27.jpg'),
#  WindowsPath('testset/testset/img270.jpg'),
#  WindowsPath('testset/testset/img271.jpg'),
#  WindowsPath('testset/testset/img272.jpg'),
#  WindowsPath('testset/testset/img273.jpg'),
#  WindowsPath('testset/testset/img274.jpg'),
#  WindowsPath('testset/testset/img275.jpg'),
#  WindowsPath('testset/testset/img276.jpg'),
#  WindowsPath('testset/testset/img277.jpg'),
#  WindowsPath('testset/testset/img278.jpg'),
#  WindowsPath('testset/testset/img279.jpg'),
#  WindowsPath('testset/testset/img28.jpg'),
#  WindowsPath('testset/testset/img280.jpg'),
#  WindowsPath('testset/testset/img281.jpg'),
#  WindowsPath('testset/testset/img282.jpg'),
#  WindowsPath('testset/testset/img283.jpg'),
#  WindowsPath('testset/testset/img284.jpg'),
#  WindowsPath('testset/testset/img285.jpg'),
#  WindowsPath('testset/testset/img286.jpg'),
#  WindowsPath('testset/testset/img287.jpg'),
#  WindowsPath('testset/testset/img288.jpg'),
#  WindowsPath('testset/testset/img289.jpg'),
#  WindowsPath('testset/testset/img29.jpg'),
#  WindowsPath('testset/testset/img290.jpg'),
#  WindowsPath('testset/testset/img291.jpg'),
#  WindowsPath('testset/testset/img292.jpg'),
#  WindowsPath('testset/testset/img293.jpg'),
#  WindowsPath('testset/testset/img294.jpg'),
#  WindowsPath('testset/testset/img295.jpg'),
#  WindowsPath('testset/testset/img296.jpg'),
#  WindowsPath('testset/testset/img297.jpg'),
#  WindowsPath('testset/testset/img298.jpg'),
#  WindowsPath('testset/testset/img299.jpg'),
#  WindowsPath('testset/testset/img3.jpg'),
#  WindowsPath('testset/testset/img30.jpg'),
#  WindowsPath('testset/testset/img300.jpg'),
#  WindowsPath('testset/testset/img301.jpg'),
#  WindowsPath('testset/testset/img302.jpg'),
#  WindowsPath('testset/testset/img303.jpg'),
#  WindowsPath('testset/testset/img304.jpg'),
#  WindowsPath('testset/testset/img305.jpg'),
#  WindowsPath('testset/testset/img306.jpg'),
#  WindowsPath('testset/testset/img307.jpg'),
#  WindowsPath('testset/testset/img308.jpg'),
#  WindowsPath('testset/testset/img309.jpg'),
#  WindowsPath('testset/testset/img31.jpg'),
#  WindowsPath('testset/testset/img310.jpg'),
#  WindowsPath('testset/testset/img311.jpg'),
#  WindowsPath('testset/testset/img312.jpg'),
#  WindowsPath('testset/testset/img313.jpg'),
#  WindowsPath('testset/testset/img314.jpg'),
#  WindowsPath('testset/testset/img315.jpg'),
#  WindowsPath('testset/testset/img316.jpg'),
#  WindowsPath('testset/testset/img317.jpg'),
#  WindowsPath('testset/testset/img318.jpg'),
#  WindowsPath('testset/testset/img319.jpg'),
#  WindowsPath('testset/testset/img32.jpg'),
#  WindowsPath('testset/testset/img320.jpg'),
#  WindowsPath('testset/testset/img321.jpg'),
#  WindowsPath('testset/testset/img322.jpg'),
#  WindowsPath('testset/testset/img323.jpg'),
#  WindowsPath('testset/testset/img324.jpg'),
#  WindowsPath('testset/testset/img325.jpg'),
#  WindowsPath('testset/testset/img326.jpg'),
#  WindowsPath('testset/testset/img327.jpg'),
#  WindowsPath('testset/testset/img328.jpg'),
#  WindowsPath('testset/testset/img329.jpg'),
#  WindowsPath('testset/testset/img33.jpg'),
#  WindowsPath('testset/testset/img330.jpg'),
#  WindowsPath('testset/testset/img331.jpg'),
#  WindowsPath('testset/testset/img332.jpg'),
#  WindowsPath('testset/testset/img333.jpg'),
#  WindowsPath('testset/testset/img334.jpg'),
#  WindowsPath('testset/testset/img335.jpg'),
#  WindowsPath('testset/testset/img336.jpg'),
#  WindowsPath('testset/testset/img337.jpg'),
#  WindowsPath('testset/testset/img338.jpg'),
#  WindowsPath('testset/testset/img339.jpg'),
#  WindowsPath('testset/testset/img34.jpg'),
#  WindowsPath('testset/testset/img340.jpg'),
#  WindowsPath('testset/testset/img341.jpg'),
#  WindowsPath('testset/testset/img342.jpg'),
#  WindowsPath('testset/testset/img343.jpg'),
#  WindowsPath('testset/testset/img344.jpg'),
#  WindowsPath('testset/testset/img345.jpg'),
#  WindowsPath('testset/testset/img346.jpg'),
#  WindowsPath('testset/testset/img347.jpg'),
#  WindowsPath('testset/testset/img348.jpg'),
#  WindowsPath('testset/testset/img349.jpg'),
#  WindowsPath('testset/testset/img35.jpg'),
#  WindowsPath('testset/testset/img350.jpg'),
#  WindowsPath('testset/testset/img351.jpg'),
#  WindowsPath('testset/testset/img352.jpg'),
#  WindowsPath('testset/testset/img353.jpg'),
#  WindowsPath('testset/testset/img354.jpg'),
#  WindowsPath('testset/testset/img355.jpg'),
#  WindowsPath('testset/testset/img356.jpg'),
#  WindowsPath('testset/testset/img357.jpg'),
#  WindowsPath('testset/testset/img358.jpg'),
#  WindowsPath('testset/testset/img359.jpg'),
#  WindowsPath('testset/testset/img36.jpg'),
#  WindowsPath('testset/testset/img360.jpg'),
#  WindowsPath('testset/testset/img361.jpg'),
#  WindowsPath('testset/testset/img362.jpg'),
#  WindowsPath('testset/testset/img363.jpg'),
#  WindowsPath('testset/testset/img364.jpg'),
#  WindowsPath('testset/testset/img365.jpg'),
#  WindowsPath('testset/testset/img366.jpg'),
#  WindowsPath('testset/testset/img367.jpg'),
#  WindowsPath('testset/testset/img368.jpg'),
#  WindowsPath('testset/testset/img369.jpg'),
#  WindowsPath('testset/testset/img37.jpg'),
#  WindowsPath('testset/testset/img370.jpg'),
#  WindowsPath('testset/testset/img371.jpg'),
#  WindowsPath('testset/testset/img372.jpg'),
#  WindowsPath('testset/testset/img373.jpg'),
#  WindowsPath('testset/testset/img374.jpg'),
#  WindowsPath('testset/testset/img375.jpg'),
#  WindowsPath('testset/testset/img376.jpg'),
#  WindowsPath('testset/testset/img377.jpg'),
#  WindowsPath('testset/testset/img378.jpg'),
#  WindowsPath('testset/testset/img379.jpg'),
#  WindowsPath('testset/testset/img38.jpg'),
#  WindowsPath('testset/testset/img380.jpg'),
#  WindowsPath('testset/testset/img381.jpg'),
#  WindowsPath('testset/testset/img382.jpg'),
#  WindowsPath('testset/testset/img383.jpg'),
#  WindowsPath('testset/testset/img384.jpg'),
#  WindowsPath('testset/testset/img385.jpg'),
#  WindowsPath('testset/testset/img386.jpg'),
#  WindowsPath('testset/testset/img387.jpg'),
#  WindowsPath('testset/testset/img388.jpg'),
#  WindowsPath('testset/testset/img389.jpg'),
#  WindowsPath('testset/testset/img39.jpg'),
#  WindowsPath('testset/testset/img390.jpg'),
#  WindowsPath('testset/testset/img391.jpg'),
#  WindowsPath('testset/testset/img392.jpg'),
#  WindowsPath('testset/testset/img393.jpg'),
#  WindowsPath('testset/testset/img394.jpg'),
#  WindowsPath('testset/testset/img395.jpg'),
#  WindowsPath('testset/testset/img396.jpg'),
#  WindowsPath('testset/testset/img397.jpg'),
#  WindowsPath('testset/testset/img398.jpg'),
#  WindowsPath('testset/testset/img399.jpg'),
#  WindowsPath('testset/testset/img4.jpg'),
#  WindowsPath('testset/testset/img40.jpg'),
#  WindowsPath('testset/testset/img400.jpg'),
#  WindowsPath('testset/testset/img401.jpg'),
#  WindowsPath('testset/testset/img402.jpg'),
#  WindowsPath('testset/testset/img403.jpg'),
#  WindowsPath('testset/testset/img404.jpg'),
#  WindowsPath('testset/testset/img405.jpg'),
#  WindowsPath('testset/testset/img406.jpg'),
#  WindowsPath('testset/testset/img407.jpg'),
#  WindowsPath('testset/testset/img408.jpg'),
#  WindowsPath('testset/testset/img409.jpg'),
#  WindowsPath('testset/testset/img41.jpg'),
#  WindowsPath('testset/testset/img410.jpg'),
#  WindowsPath('testset/testset/img411.jpg'),
#  WindowsPath('testset/testset/img412.jpg'),
#  WindowsPath('testset/testset/img413.jpg'),
#  WindowsPath('testset/testset/img414.jpg'),
#  WindowsPath('testset/testset/img415.jpg'),
#  WindowsPath('testset/testset/img416.jpg'),
#  WindowsPath('testset/testset/img417.jpg'),
#  WindowsPath('testset/testset/img418.jpg'),
#  WindowsPath('testset/testset/img419.jpg'),
#  WindowsPath('testset/testset/img42.jpg'),
#  WindowsPath('testset/testset/img420.jpg'),
#  WindowsPath('testset/testset/img421.jpg'),
#  WindowsPath('testset/testset/img422.jpg'),
#  WindowsPath('testset/testset/img423.jpg'),
#  WindowsPath('testset/testset/img424.jpg'),
#  WindowsPath('testset/testset/img425.jpg'),
#  WindowsPath('testset/testset/img426.jpg'),
#  WindowsPath('testset/testset/img427.jpg'),
#  WindowsPath('testset/testset/img428.jpg'),
#  WindowsPath('testset/testset/img429.jpg'),
#  WindowsPath('testset/testset/img43.jpg'),
#  WindowsPath('testset/testset/img430.jpg'),
#  WindowsPath('testset/testset/img431.jpg'),
#  WindowsPath('testset/testset/img432.jpg'),
#  WindowsPath('testset/testset/img433.jpg'),
#  WindowsPath('testset/testset/img434.jpg'),
#  WindowsPath('testset/testset/img435.jpg'),
#  WindowsPath('testset/testset/img436.jpg'),
#  WindowsPath('testset/testset/img437.jpg'),
#  WindowsPath('testset/testset/img438.jpg'),
#  WindowsPath('testset/testset/img439.jpg'),
#  WindowsPath('testset/testset/img44.jpg'),
#  WindowsPath('testset/testset/img440.jpg'),
#  WindowsPath('testset/testset/img441.jpg'),
#  WindowsPath('testset/testset/img442.jpg'),
#  WindowsPath('testset/testset/img443.jpg'),
#  WindowsPath('testset/testset/img444.jpg'),
#  WindowsPath('testset/testset/img445.jpg'),
#  WindowsPath('testset/testset/img446.jpg'),
#  WindowsPath('testset/testset/img447.jpg'),
#  WindowsPath('testset/testset/img448.jpg'),
#  WindowsPath('testset/testset/img449.jpg'),
#  WindowsPath('testset/testset/img45.jpg'),
#  WindowsPath('testset/testset/img450.jpg'),
#  WindowsPath('testset/testset/img451.jpg'),
#  WindowsPath('testset/testset/img452.jpg'),
#  WindowsPath('testset/testset/img453.jpg'),
#  WindowsPath('testset/testset/img454.jpg'),
#  WindowsPath('testset/testset/img455.jpg'),
#  WindowsPath('testset/testset/img456.jpg'),
#  WindowsPath('testset/testset/img457.jpg'),
#  WindowsPath('testset/testset/img458.jpg'),
#  WindowsPath('testset/testset/img459.jpg'),
#  WindowsPath('testset/testset/img46.jpg'),
#  WindowsPath('testset/testset/img460.jpg'),
#  WindowsPath('testset/testset/img461.jpg'),
#  WindowsPath('testset/testset/img462.jpg'),
#  WindowsPath('testset/testset/img463.jpg'),
#  WindowsPath('testset/testset/img464.jpg'),
#  WindowsPath('testset/testset/img465.jpg'),
#  WindowsPath('testset/testset/img466.jpg'),
#  WindowsPath('testset/testset/img467.jpg'),
#  WindowsPath('testset/testset/img468.jpg'),
#  WindowsPath('testset/testset/img469.jpg'),
#  WindowsPath('testset/testset/img47.jpg'),
#  WindowsPath('testset/testset/img470.jpg'),
#  WindowsPath('testset/testset/img471.jpg'),
#  WindowsPath('testset/testset/img472.jpg'),
#  WindowsPath('testset/testset/img473.jpg'),
#  WindowsPath('testset/testset/img474.jpg'),
#  WindowsPath('testset/testset/img475.jpg'),
#  WindowsPath('testset/testset/img476.jpg'),
#  WindowsPath('testset/testset/img477.jpg'),
#  WindowsPath('testset/testset/img478.jpg'),
#  WindowsPath('testset/testset/img479.jpg'),
#  WindowsPath('testset/testset/img48.jpg'),
#  WindowsPath('testset/testset/img480.jpg'),
#  WindowsPath('testset/testset/img481.jpg'),
#  WindowsPath('testset/testset/img482.jpg'),
#  WindowsPath('testset/testset/img483.jpg'),
#  WindowsPath('testset/testset/img484.jpg'),
#  WindowsPath('testset/testset/img485.jpg'),
#  WindowsPath('testset/testset/img486.jpg'),
#  WindowsPath('testset/testset/img487.jpg'),
#  WindowsPath('testset/testset/img488.jpg'),
#  WindowsPath('testset/testset/img489.jpg'),
#  WindowsPath('testset/testset/img49.jpg'),
#  WindowsPath('testset/testset/img490.jpg'),
#  WindowsPath('testset/testset/img491.jpg'),
#  WindowsPath('testset/testset/img492.jpg'),
#  WindowsPath('testset/testset/img493.jpg'),
#  WindowsPath('testset/testset/img494.jpg'),
#  WindowsPath('testset/testset/img495.jpg'),
#  WindowsPath('testset/testset/img496.jpg'),
#  WindowsPath('testset/testset/img497.jpg'),
#  WindowsPath('testset/testset/img498.jpg'),
#  WindowsPath('testset/testset/img499.jpg'),
#  WindowsPath('testset/testset/img5.jpg'),
#  WindowsPath('testset/testset/img50.jpg'),
#  WindowsPath('testset/testset/img500.jpg'),
#  WindowsPath('testset/testset/img501.jpg'),
#  WindowsPath('testset/testset/img502.jpg'),
#  WindowsPath('testset/testset/img503.jpg'),
#  WindowsPath('testset/testset/img504.jpg'),
#  WindowsPath('testset/testset/img505.jpg'),
#  WindowsPath('testset/testset/img506.jpg'),
#  WindowsPath('testset/testset/img507.jpg'),
#  WindowsPath('testset/testset/img508.jpg'),
#  WindowsPath('testset/testset/img509.jpg'),
#  WindowsPath('testset/testset/img51.jpg'),
#  WindowsPath('testset/testset/img510.jpg'),
#  WindowsPath('testset/testset/img511.jpg'),
#  WindowsPath('testset/testset/img512.jpg'),
#  WindowsPath('testset/testset/img513.jpg'),
#  WindowsPath('testset/testset/img514.jpg'),
#  WindowsPath('testset/testset/img515.jpg'),
#  WindowsPath('testset/testset/img516.jpg'),
#  WindowsPath('testset/testset/img517.jpg'),
#  WindowsPath('testset/testset/img518.jpg'),
#  WindowsPath('testset/testset/img519.jpg'),
#  WindowsPath('testset/testset/img52.jpg'),
#  WindowsPath('testset/testset/img520.jpg'),
#  WindowsPath('testset/testset/img521.jpg'),
#  WindowsPath('testset/testset/img522.jpg'),
#  WindowsPath('testset/testset/img523.jpg'),
#  WindowsPath('testset/testset/img524.jpg'),
#  WindowsPath('testset/testset/img525.jpg'),
#  WindowsPath('testset/testset/img526.jpg'),
#  WindowsPath('testset/testset/img527.jpg'),
#  WindowsPath('testset/testset/img528.jpg'),
#  WindowsPath('testset/testset/img529.jpg'),
#  WindowsPath('testset/testset/img53.jpg'),
#  WindowsPath('testset/testset/img530.jpg'),
#  WindowsPath('testset/testset/img531.jpg'),
#  WindowsPath('testset/testset/img532.jpg'),
#  WindowsPath('testset/testset/img533.jpg'),
#  WindowsPath('testset/testset/img534.jpg'),
#  WindowsPath('testset/testset/img535.jpg'),
#  WindowsPath('testset/testset/img536.jpg'),
#  WindowsPath('testset/testset/img537.jpg'),
#  WindowsPath('testset/testset/img538.jpg'),
#  WindowsPath('testset/testset/img539.jpg'),
#  WindowsPath('testset/testset/img54.jpg'),
#  WindowsPath('testset/testset/img540.jpg'),
#  WindowsPath('testset/testset/img541.jpg'),
#  WindowsPath('testset/testset/img542.jpg'),
#  WindowsPath('testset/testset/img543.jpg'),
#  WindowsPath('testset/testset/img544.jpg'),
#  WindowsPath('testset/testset/img545.jpg'),
#  WindowsPath('testset/testset/img546.jpg'),
#  WindowsPath('testset/testset/img547.jpg'),
#  WindowsPath('testset/testset/img548.jpg'),
#  WindowsPath('testset/testset/img549.jpg'),
#  WindowsPath('testset/testset/img55.jpg'),
#  WindowsPath('testset/testset/img550.jpg'),
#  WindowsPath('testset/testset/img551.jpg'),
#  WindowsPath('testset/testset/img552.jpg'),
#  WindowsPath('testset/testset/img553.jpg'),
#  WindowsPath('testset/testset/img554.jpg'),
#  WindowsPath('testset/testset/img555.jpg'),
#  WindowsPath('testset/testset/img556.jpg'),
#  WindowsPath('testset/testset/img557.jpg'),
#  WindowsPath('testset/testset/img558.jpg'),
#  WindowsPath('testset/testset/img559.jpg'),
#  WindowsPath('testset/testset/img56.jpg'),
#  WindowsPath('testset/testset/img560.jpg'),
#  WindowsPath('testset/testset/img561.jpg'),
#  WindowsPath('testset/testset/img562.jpg'),
#  WindowsPath('testset/testset/img563.jpg'),
#  WindowsPath('testset/testset/img564.jpg'),
#  WindowsPath('testset/testset/img565.jpg'),
#  WindowsPath('testset/testset/img566.jpg'),
#  WindowsPath('testset/testset/img567.jpg'),
#  WindowsPath('testset/testset/img568.jpg'),
#  WindowsPath('testset/testset/img569.jpg'),
#  WindowsPath('testset/testset/img57.jpg'),
#  WindowsPath('testset/testset/img570.jpg'),
#  WindowsPath('testset/testset/img571.jpg'),
#  WindowsPath('testset/testset/img572.jpg'),
#  WindowsPath('testset/testset/img573.jpg'),
#  WindowsPath('testset/testset/img574.jpg'),
#  WindowsPath('testset/testset/img575.jpg'),
#  WindowsPath('testset/testset/img576.jpg'),
#  WindowsPath('testset/testset/img577.jpg'),
#  WindowsPath('testset/testset/img578.jpg'),
#  WindowsPath('testset/testset/img579.jpg'),
#  WindowsPath('testset/testset/img58.jpg'),
#  WindowsPath('testset/testset/img580.jpg'),
#  WindowsPath('testset/testset/img581.jpg'),
#  WindowsPath('testset/testset/img582.jpg'),
#  WindowsPath('testset/testset/img583.jpg'),
#  WindowsPath('testset/testset/img584.jpg'),
#  WindowsPath('testset/testset/img585.jpg'),
#  WindowsPath('testset/testset/img586.jpg'),
#  WindowsPath('testset/testset/img587.jpg'),
#  WindowsPath('testset/testset/img588.jpg'),
#  WindowsPath('testset/testset/img589.jpg'),
#  WindowsPath('testset/testset/img59.jpg'),
#  WindowsPath('testset/testset/img590.jpg'),
#  WindowsPath('testset/testset/img591.jpg'),
#  WindowsPath('testset/testset/img592.jpg'),
#  WindowsPath('testset/testset/img593.jpg'),
#  WindowsPath('testset/testset/img594.jpg'),
#  WindowsPath('testset/testset/img595.jpg'),
#  WindowsPath('testset/testset/img596.jpg'),
#  WindowsPath('testset/testset/img597.jpg'),
#  WindowsPath('testset/testset/img598.jpg'),
#  WindowsPath('testset/testset/img599.jpg'),
#  WindowsPath('testset/testset/img6.jpg'),
#  WindowsPath('testset/testset/img60.jpg'),
#  WindowsPath('testset/testset/img600.jpg'),
#  WindowsPath('testset/testset/img601.jpg'),
#  WindowsPath('testset/testset/img602.jpg'),
#  WindowsPath('testset/testset/img603.jpg'),
#  WindowsPath('testset/testset/img604.jpg'),
#  WindowsPath('testset/testset/img605.jpg'),
#  WindowsPath('testset/testset/img606.jpg'),
#  WindowsPath('testset/testset/img607.jpg'),
#  WindowsPath('testset/testset/img608.jpg'),
#  WindowsPath('testset/testset/img609.jpg'),
#  WindowsPath('testset/testset/img61.jpg'),
#  WindowsPath('testset/testset/img610.jpg'),
#  WindowsPath('testset/testset/img611.jpg'),
#  WindowsPath('testset/testset/img612.jpg'),
#  WindowsPath('testset/testset/img613.jpg'),
#  WindowsPath('testset/testset/img614.jpg'),
#  WindowsPath('testset/testset/img615.jpg'),
#  WindowsPath('testset/testset/img616.jpg'),
#  WindowsPath('testset/testset/img617.jpg'),
#  WindowsPath('testset/testset/img618.jpg'),
#  WindowsPath('testset/testset/img619.jpg'),
#  WindowsPath('testset/testset/img62.jpg'),
#  WindowsPath('testset/testset/img620.jpg'),
#  WindowsPath('testset/testset/img621.jpg'),
#  WindowsPath('testset/testset/img622.jpg'),
#  WindowsPath('testset/testset/img623.jpg'),
#  WindowsPath('testset/testset/img624.jpg'),
#  WindowsPath('testset/testset/img625.jpg'),
#  WindowsPath('testset/testset/img626.jpg'),
#  WindowsPath('testset/testset/img627.jpg'),
#  WindowsPath('testset/testset/img628.jpg'),
#  WindowsPath('testset/testset/img629.jpg'),
#  WindowsPath('testset/testset/img63.jpg'),
#  WindowsPath('testset/testset/img630.jpg'),
#  WindowsPath('testset/testset/img631.jpg'),
#  WindowsPath('testset/testset/img632.jpg'),
#  WindowsPath('testset/testset/img633.jpg'),
#  WindowsPath('testset/testset/img634.jpg'),
#  WindowsPath('testset/testset/img635.jpg'),
#  WindowsPath('testset/testset/img636.jpg'),
#  WindowsPath('testset/testset/img637.jpg'),
#  WindowsPath('testset/testset/img638.jpg'),
#  WindowsPath('testset/testset/img639.jpg'),
#  WindowsPath('testset/testset/img64.jpg'),
#  WindowsPath('testset/testset/img640.jpg'),
#  WindowsPath('testset/testset/img641.jpg'),
#  WindowsPath('testset/testset/img642.jpg'),
#  WindowsPath('testset/testset/img643.jpg'),
#  WindowsPath('testset/testset/img644.jpg'),
#  WindowsPath('testset/testset/img645.jpg'),
#  WindowsPath('testset/testset/img646.jpg'),
#  WindowsPath('testset/testset/img647.jpg'),
#  WindowsPath('testset/testset/img648.jpg'),
#  WindowsPath('testset/testset/img649.jpg'),
#  WindowsPath('testset/testset/img65.jpg'),
#  WindowsPath('testset/testset/img650.jpg'),
#  WindowsPath('testset/testset/img651.jpg'),
#  WindowsPath('testset/testset/img652.jpg'),
#  WindowsPath('testset/testset/img653.jpg'),
#  WindowsPath('testset/testset/img654.jpg'),
#  WindowsPath('testset/testset/img655.jpg'),
#  WindowsPath('testset/testset/img656.jpg'),
#  WindowsPath('testset/testset/img657.jpg'),
#  WindowsPath('testset/testset/img658.jpg'),
#  WindowsPath('testset/testset/img659.jpg'),
#  WindowsPath('testset/testset/img66.jpg'),
#  WindowsPath('testset/testset/img660.jpg'),
#  WindowsPath('testset/testset/img661.jpg'),
#  WindowsPath('testset/testset/img662.jpg'),
#  WindowsPath('testset/testset/img663.jpg'),
#  WindowsPath('testset/testset/img664.jpg'),
#  WindowsPath('testset/testset/img665.jpg'),
#  WindowsPath('testset/testset/img666.jpg'),
#  WindowsPath('testset/testset/img667.jpg'),
#  WindowsPath('testset/testset/img668.jpg'),
#  WindowsPath('testset/testset/img669.jpg'),
#  WindowsPath('testset/testset/img67.jpg'),
#  WindowsPath('testset/testset/img670.jpg'),
#  WindowsPath('testset/testset/img671.jpg'),
#  WindowsPath('testset/testset/img672.jpg'),
#  WindowsPath('testset/testset/img673.jpg'),
#  WindowsPath('testset/testset/img674.jpg'),
#  WindowsPath('testset/testset/img675.jpg'),
#  WindowsPath('testset/testset/img676.jpg'),
#  WindowsPath('testset/testset/img677.jpg'),
#  WindowsPath('testset/testset/img678.jpg'),
#  WindowsPath('testset/testset/img679.jpg'),
#  WindowsPath('testset/testset/img68.jpg'),
#  WindowsPath('testset/testset/img680.jpg'),
#  WindowsPath('testset/testset/img681.jpg'),
#  WindowsPath('testset/testset/img682.jpg'),
#  WindowsPath('testset/testset/img683.jpg'),
#  WindowsPath('testset/testset/img684.jpg'),
#  WindowsPath('testset/testset/img685.jpg'),
#  WindowsPath('testset/testset/img686.jpg'),
#  WindowsPath('testset/testset/img687.jpg'),
#  WindowsPath('testset/testset/img688.jpg'),
#  WindowsPath('testset/testset/img689.jpg'),
#  WindowsPath('testset/testset/img69.jpg'),
#  WindowsPath('testset/testset/img690.jpg'),
#  WindowsPath('testset/testset/img691.jpg'),
#  WindowsPath('testset/testset/img692.jpg'),
#  WindowsPath('testset/testset/img693.jpg'),
#  WindowsPath('testset/testset/img694.jpg'),
#  WindowsPath('testset/testset/img695.jpg'),
#  WindowsPath('testset/testset/img696.jpg'),
#  WindowsPath('testset/testset/img697.jpg'),
#  WindowsPath('testset/testset/img698.jpg'),
#  WindowsPath('testset/testset/img699.jpg'),
#  WindowsPath('testset/testset/img7.jpg'),
#  WindowsPath('testset/testset/img70.jpg'),
#  WindowsPath('testset/testset/img700.jpg'),
#  WindowsPath('testset/testset/img701.jpg'),
#  WindowsPath('testset/testset/img702.jpg'),
#  WindowsPath('testset/testset/img703.jpg'),
#  WindowsPath('testset/testset/img704.jpg'),
#  WindowsPath('testset/testset/img705.jpg'),
#  WindowsPath('testset/testset/img706.jpg'),
#  WindowsPath('testset/testset/img707.jpg'),
#  WindowsPath('testset/testset/img708.jpg'),
#  WindowsPath('testset/testset/img709.jpg'),
#  WindowsPath('testset/testset/img71.jpg'),
#  WindowsPath('testset/testset/img710.jpg'),
#  WindowsPath('testset/testset/img711.jpg'),
#  WindowsPath('testset/testset/img712.jpg'),
#  WindowsPath('testset/testset/img713.jpg'),
#  WindowsPath('testset/testset/img714.jpg'),
#  WindowsPath('testset/testset/img715.jpg'),
#  WindowsPath('testset/testset/img716.jpg'),
#  WindowsPath('testset/testset/img717.jpg'),
#  WindowsPath('testset/testset/img718.jpg'),
#  WindowsPath('testset/testset/img719.jpg'),
#  WindowsPath('testset/testset/img72.jpg'),
#  WindowsPath('testset/testset/img720.jpg'),
#  WindowsPath('testset/testset/img721.jpg'),
#  WindowsPath('testset/testset/img722.jpg'),
#  WindowsPath('testset/testset/img723.jpg'),
#  WindowsPath('testset/testset/img724.jpg'),
#  WindowsPath('testset/testset/img725.jpg'),
#  WindowsPath('testset/testset/img726.jpg'),
#  WindowsPath('testset/testset/img727.jpg'),
#  WindowsPath('testset/testset/img728.jpg'),
#  WindowsPath('testset/testset/img729.jpg'),
#  WindowsPath('testset/testset/img73.jpg'),
#  WindowsPath('testset/testset/img730.jpg'),
#  WindowsPath('testset/testset/img731.jpg'),
#  WindowsPath('testset/testset/img732.jpg'),
#  WindowsPath('testset/testset/img733.jpg'),
#  WindowsPath('testset/testset/img734.jpg'),
#  WindowsPath('testset/testset/img735.jpg'),
#  WindowsPath('testset/testset/img736.jpg'),
#  WindowsPath('testset/testset/img737.jpg'),
#  WindowsPath('testset/testset/img738.jpg'),
#  WindowsPath('testset/testset/img739.jpg'),
#  WindowsPath('testset/testset/img74.jpg'),
#  WindowsPath('testset/testset/img740.jpg'),
#  WindowsPath('testset/testset/img741.jpg'),
#  WindowsPath('testset/testset/img742.jpg'),
#  WindowsPath('testset/testset/img743.jpg'),
#  WindowsPath('testset/testset/img744.jpg'),
#  WindowsPath('testset/testset/img745.jpg'),
#  WindowsPath('testset/testset/img746.jpg'),
#  WindowsPath('testset/testset/img747.jpg'),
#  WindowsPath('testset/testset/img748.jpg'),
#  WindowsPath('testset/testset/img749.jpg'),
#  WindowsPath('testset/testset/img75.jpg'),
#  WindowsPath('testset/testset/img750.jpg'),
#  WindowsPath('testset/testset/img751.jpg'),
#  WindowsPath('testset/testset/img752.jpg'),
#  WindowsPath('testset/testset/img753.jpg'),
#  WindowsPath('testset/testset/img754.jpg'),
#  WindowsPath('testset/testset/img755.jpg'),
#  WindowsPath('testset/testset/img756.jpg'),
#  WindowsPath('testset/testset/img757.jpg'),
#  WindowsPath('testset/testset/img758.jpg'),
#  WindowsPath('testset/testset/img759.jpg'),
#  WindowsPath('testset/testset/img76.jpg'),
#  WindowsPath('testset/testset/img760.jpg'),
#  WindowsPath('testset/testset/img761.jpg'),
#  WindowsPath('testset/testset/img762.jpg'),
#  WindowsPath('testset/testset/img763.jpg'),
#  WindowsPath('testset/testset/img764.jpg'),
#  WindowsPath('testset/testset/img765.jpg'),
#  WindowsPath('testset/testset/img766.jpg'),
#  WindowsPath('testset/testset/img767.jpg'),
#  WindowsPath('testset/testset/img768.jpg'),
#  WindowsPath('testset/testset/img769.jpg'),
#  WindowsPath('testset/testset/img77.jpg'),
#  WindowsPath('testset/testset/img770.jpg'),
#  WindowsPath('testset/testset/img771.jpg'),
#  WindowsPath('testset/testset/img772.jpg'),
#  WindowsPath('testset/testset/img773.jpg'),
#  WindowsPath('testset/testset/img774.jpg'),
#  WindowsPath('testset/testset/img775.jpg'),
#  WindowsPath('testset/testset/img776.jpg'),
#  WindowsPath('testset/testset/img777.jpg'),
#  WindowsPath('testset/testset/img778.jpg'),
#  WindowsPath('testset/testset/img779.jpg'),
#  WindowsPath('testset/testset/img78.jpg'),
#  WindowsPath('testset/testset/img780.jpg'),
#  WindowsPath('testset/testset/img781.jpg'),
#  WindowsPath('testset/testset/img782.jpg'),
#  WindowsPath('testset/testset/img783.jpg'),
#  WindowsPath('testset/testset/img784.jpg'),
#  WindowsPath('testset/testset/img785.jpg'),
#  WindowsPath('testset/testset/img786.jpg'),
#  WindowsPath('testset/testset/img787.jpg'),
#  WindowsPath('testset/testset/img788.jpg'),
#  WindowsPath('testset/testset/img789.jpg'),
#  WindowsPath('testset/testset/img79.jpg'),
#  WindowsPath('testset/testset/img790.jpg'),
#  WindowsPath('testset/testset/img791.jpg'),
#  WindowsPath('testset/testset/img792.jpg'),
#  WindowsPath('testset/testset/img793.jpg'),
#  WindowsPath('testset/testset/img794.jpg'),
#  WindowsPath('testset/testset/img795.jpg'),
#  WindowsPath('testset/testset/img796.jpg'),
#  WindowsPath('testset/testset/img797.jpg'),
#  WindowsPath('testset/testset/img798.jpg'),
#  WindowsPath('testset/testset/img799.jpg'),
#  WindowsPath('testset/testset/img8.jpg'),
#  WindowsPath('testset/testset/img80.jpg'),
#  WindowsPath('testset/testset/img800.jpg'),
#  WindowsPath('testset/testset/img801.jpg'),
#  WindowsPath('testset/testset/img802.jpg'),
#  WindowsPath('testset/testset/img803.jpg'),
#  WindowsPath('testset/testset/img804.jpg'),
#  WindowsPath('testset/testset/img805.jpg'),
#  WindowsPath('testset/testset/img806.jpg'),
#  WindowsPath('testset/testset/img807.jpg'),
#  WindowsPath('testset/testset/img808.jpg'),
#  WindowsPath('testset/testset/img809.jpg'),
#  WindowsPath('testset/testset/img81.jpg'),
#  WindowsPath('testset/testset/img810.jpg'),
#  WindowsPath('testset/testset/img811.jpg'),
#  WindowsPath('testset/testset/img812.jpg'),
#  WindowsPath('testset/testset/img813.jpg'),
#  WindowsPath('testset/testset/img814.jpg'),
#  WindowsPath('testset/testset/img815.jpg'),
#  WindowsPath('testset/testset/img816.jpg'),
#  WindowsPath('testset/testset/img817.jpg'),
#  WindowsPath('testset/testset/img818.jpg'),
#  WindowsPath('testset/testset/img819.jpg'),
#  WindowsPath('testset/testset/img82.jpg'),
#  WindowsPath('testset/testset/img820.jpg'),
#  WindowsPath('testset/testset/img821.jpg'),
#  WindowsPath('testset/testset/img822.jpg'),
#  WindowsPath('testset/testset/img823.jpg'),
#  WindowsPath('testset/testset/img824.jpg'),
#  WindowsPath('testset/testset/img825.jpg'),
#  WindowsPath('testset/testset/img826.jpg'),
#  WindowsPath('testset/testset/img827.jpg'),
#  WindowsPath('testset/testset/img828.jpg'),
#  WindowsPath('testset/testset/img829.jpg'),
#  WindowsPath('testset/testset/img83.jpg'),
#  WindowsPath('testset/testset/img830.jpg'),
#  WindowsPath('testset/testset/img831.jpg'),
#  WindowsPath('testset/testset/img832.jpg'),
#  WindowsPath('testset/testset/img833.jpg'),
#  WindowsPath('testset/testset/img834.jpg'),
#  WindowsPath('testset/testset/img835.jpg'),
#  WindowsPath('testset/testset/img836.jpg'),
#  WindowsPath('testset/testset/img837.jpg'),
#  WindowsPath('testset/testset/img838.jpg'),
#  WindowsPath('testset/testset/img839.jpg'),
#  WindowsPath('testset/testset/img84.jpg'),
#  WindowsPath('testset/testset/img840.jpg'),
#  WindowsPath('testset/testset/img841.jpg'),
#  WindowsPath('testset/testset/img842.jpg'),
#  WindowsPath('testset/testset/img843.jpg'),
#  WindowsPath('testset/testset/img844.jpg'),
#  WindowsPath('testset/testset/img845.jpg'),
#  WindowsPath('testset/testset/img846.jpg'),
#  WindowsPath('testset/testset/img847.jpg'),
#  WindowsPath('testset/testset/img848.jpg'),
#  WindowsPath('testset/testset/img849.jpg'),
#  WindowsPath('testset/testset/img85.jpg'),
#  WindowsPath('testset/testset/img850.jpg'),
#  WindowsPath('testset/testset/img851.jpg'),
#  WindowsPath('testset/testset/img852.jpg'),
#  WindowsPath('testset/testset/img853.jpg'),
#  WindowsPath('testset/testset/img854.jpg'),
#  WindowsPath('testset/testset/img855.jpg'),
#  WindowsPath('testset/testset/img856.jpg'),
#  WindowsPath('testset/testset/img857.jpg'),
#  WindowsPath('testset/testset/img858.jpg'),
#  WindowsPath('testset/testset/img859.jpg'),
#  WindowsPath('testset/testset/img86.jpg'),
#  WindowsPath('testset/testset/img860.jpg'),
#  WindowsPath('testset/testset/img861.jpg'),
#  WindowsPath('testset/testset/img862.jpg'),
#  WindowsPath('testset/testset/img863.jpg'),
#  WindowsPath('testset/testset/img864.jpg'),
#  WindowsPath('testset/testset/img865.jpg'),
#  WindowsPath('testset/testset/img866.jpg'),
#  WindowsPath('testset/testset/img867.jpg'),
#  WindowsPath('testset/testset/img868.jpg'),
#  WindowsPath('testset/testset/img869.jpg'),
#  WindowsPath('testset/testset/img87.jpg'),
#  WindowsPath('testset/testset/img870.jpg'),
#  WindowsPath('testset/testset/img871.jpg'),
#  WindowsPath('testset/testset/img872.jpg'),
#  WindowsPath('testset/testset/img873.jpg'),
#  WindowsPath('testset/testset/img874.jpg'),
#  WindowsPath('testset/testset/img875.jpg'),
#  WindowsPath('testset/testset/img876.jpg'),
#  WindowsPath('testset/testset/img877.jpg'),
#  WindowsPath('testset/testset/img878.jpg'),
#  WindowsPath('testset/testset/img879.jpg'),
#  WindowsPath('testset/testset/img88.jpg'),
#  WindowsPath('testset/testset/img880.jpg'),
#  WindowsPath('testset/testset/img881.jpg'),
#  WindowsPath('testset/testset/img882.jpg'),
#  WindowsPath('testset/testset/img883.jpg'),
#  WindowsPath('testset/testset/img884.jpg'),
#  WindowsPath('testset/testset/img885.jpg'),
#  WindowsPath('testset/testset/img886.jpg'),
#  WindowsPath('testset/testset/img887.jpg'),
#  WindowsPath('testset/testset/img888.jpg'),
#  WindowsPath('testset/testset/img889.jpg'),
#  WindowsPath('testset/testset/img89.jpg'),
#  WindowsPath('testset/testset/img890.jpg'),
#  WindowsPath('testset/testset/img891.jpg'),
#  WindowsPath('testset/testset/img892.jpg'),
#  WindowsPath('testset/testset/img893.jpg'),
#  WindowsPath('testset/testset/img894.jpg'),
#  WindowsPath('testset/testset/img895.jpg'),
#  WindowsPath('testset/testset/img896.jpg'),
#  WindowsPath('testset/testset/img897.jpg'),
#  WindowsPath('testset/testset/img898.jpg'),
#  WindowsPath('testset/testset/img899.jpg'),
#  WindowsPath('testset/testset/img9.jpg'),
#  WindowsPath('testset/testset/img90.jpg'),
#  WindowsPath('testset/testset/img900.jpg'),
#  WindowsPath('testset/testset/img901.jpg'),
#  WindowsPath('testset/testset/img902.jpg'),
#  WindowsPath('testset/testset/img903.jpg'),
#  WindowsPath('testset/testset/img904.jpg'),
#  WindowsPath('testset/testset/img905.jpg'),
#  WindowsPath('testset/testset/img906.jpg'),
#  WindowsPath('testset/testset/img907.jpg'),
#  WindowsPath('testset/testset/img908.jpg'),
#  WindowsPath('testset/testset/img909.jpg'),
#  WindowsPath('testset/testset/img91.jpg'),
#  WindowsPath('testset/testset/img910.jpg'),
#  WindowsPath('testset/testset/img911.jpg'),
#  WindowsPath('testset/testset/img912.jpg'),
#  WindowsPath('testset/testset/img913.jpg'),
#  WindowsPath('testset/testset/img914.jpg'),
#  WindowsPath('testset/testset/img915.jpg'),
#  WindowsPath('testset/testset/img916.jpg'),
#  WindowsPath('testset/testset/img917.jpg'),
#  WindowsPath('testset/testset/img918.jpg'),
#  WindowsPath('testset/testset/img919.jpg'),
#  WindowsPath('testset/testset/img92.jpg'),
#  WindowsPath('testset/testset/img920.jpg'),
#  WindowsPath('testset/testset/img921.jpg'),
#  WindowsPath('testset/testset/img922.jpg'),
#  WindowsPath('testset/testset/img923.jpg'),
#  WindowsPath('testset/testset/img924.jpg'),
#  WindowsPath('testset/testset/img925.jpg'),
#  WindowsPath('testset/testset/img926.jpg'),
#  WindowsPath('testset/testset/img927.jpg'),
#  WindowsPath('testset/testset/img928.jpg'),
#  WindowsPath('testset/testset/img929.jpg'),
#  WindowsPath('testset/testset/img93.jpg'),
#  WindowsPath('testset/testset/img930.jpg'),
#  WindowsPath('testset/testset/img931.jpg'),
#  WindowsPath('testset/testset/img932.jpg'),
#  WindowsPath('testset/testset/img933.jpg'),
#  WindowsPath('testset/testset/img934.jpg'),
#  WindowsPath('testset/testset/img935.jpg'),
#  WindowsPath('testset/testset/img936.jpg'),
#  WindowsPath('testset/testset/img937.jpg'),
#  WindowsPath('testset/testset/img938.jpg'),
#  WindowsPath('testset/testset/img939.jpg'),
#  WindowsPath('testset/testset/img94.jpg'),
#  WindowsPath('testset/testset/img940.jpg'),
#  WindowsPath('testset/testset/img941.jpg'),
#  WindowsPath('testset/testset/img942.jpg'),
#  WindowsPath('testset/testset/img943.jpg'),
#  WindowsPath('testset/testset/img944.jpg'),
#  WindowsPath('testset/testset/img945.jpg'),
#  WindowsPath('testset/testset/img946.jpg'),
#  WindowsPath('testset/testset/img947.jpg'),
#  WindowsPath('testset/testset/img948.jpg'),
#  WindowsPath('testset/testset/img949.jpg'),
#  WindowsPath('testset/testset/img95.jpg'),
#  WindowsPath('testset/testset/img950.jpg'),
#  WindowsPath('testset/testset/img951.jpg'),
#  WindowsPath('testset/testset/img952.jpg'),
#  WindowsPath('testset/testset/img953.jpg'),
#  WindowsPath('testset/testset/img954.jpg'),
#  WindowsPath('testset/testset/img955.jpg'),
#  WindowsPath('testset/testset/img956.jpg'),
#  WindowsPath('testset/testset/img957.jpg'),
#  WindowsPath('testset/testset/img958.jpg'),
#  WindowsPath('testset/testset/img959.jpg'),
#  WindowsPath('testset/testset/img96.jpg'),
#  WindowsPath('testset/testset/img960.jpg'),
#  WindowsPath('testset/testset/img961.jpg'),
#  WindowsPath('testset/testset/img962.jpg'),
#  WindowsPath('testset/testset/img963.jpg'),
#  WindowsPath('testset/testset/img964.jpg'),
#  WindowsPath('testset/testset/img965.jpg'),
#  WindowsPath('testset/testset/img966.jpg'),
#  WindowsPath('testset/testset/img967.jpg'),
#  WindowsPath('testset/testset/img968.jpg'),
#  WindowsPath('testset/testset/img969.jpg'),
#  WindowsPath('testset/testset/img97.jpg'),
#  WindowsPath('testset/testset/img970.jpg'),
#  WindowsPath('testset/testset/img971.jpg'),
#  WindowsPath('testset/testset/img972.jpg'),
#  WindowsPath('testset/testset/img973.jpg'),
#  WindowsPath('testset/testset/img974.jpg'),
#  WindowsPath('testset/testset/img975.jpg'),
#  WindowsPath('testset/testset/img976.jpg'),
#  WindowsPath('testset/testset/img977.jpg'),
#  WindowsPath('testset/testset/img978.jpg'),
#  WindowsPath('testset/testset/img979.jpg'),
#  WindowsPath('testset/testset/img98.jpg'),
#  WindowsPath('testset/testset/img980.jpg'),
#  WindowsPath('testset/testset/img981.jpg'),
#  WindowsPath('testset/testset/img982.jpg'),
#  WindowsPath('testset/testset/img983.jpg'),
#  WindowsPath('testset/testset/img984.jpg'),
#  WindowsPath('testset/testset/img985.jpg'),
#  WindowsPath('testset/testset/img986.jpg'),
#  WindowsPath('testset/testset/img987.jpg'),
#  WindowsPath('testset/testset/img988.jpg'),
#  WindowsPath('testset/testset/img989.jpg'),
#  WindowsPath('testset/testset/img99.jpg'),
#  WindowsPath('testset/testset/img990.jpg')]

# %%
from sklearn.model_selection import train_test_split

train_val_labels = [path.parent.name for path in train_val_files]
train_files, val_files = train_test_split(train_val_files, test_size=0.25, \
                                          stratify=train_val_labels)

# %%
val_dataset = SimpsonsDataset(val_files, mode='val')

# %%
# uncomment if you have problem with pillow
# def register_extension(id, extension): Image.EXTENSION[extension.lower()] = id.upper()
# Image.register_extension = register_extension
# def register_extensions(id, extensions): 
#     for extension in extensions: register_extension(id, extension)
# Image.register_extensions = register_extensions

# %% [markdown]
# Давайте посмотрим на наших героев внутри датасета.

# %%
fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(8, 8), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    random_characters = int(np.random.uniform(0,1000))
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    img_label = " ".join([x.capitalize() for x in val_dataset.label_encoder.inverse_transform([label])[0].split('_')])
    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)
    img_label

# %% [markdown]
# Можете добавить ваши любимые сцены и классифицировать их. (веселые результаты можно кидать в чат)

# %% [markdown]
# ### Построение нейросети
#
# Запустить данную сеть будет вашим мини-заданием на первую неделю, чтобы было проще участвовать в соревновании.
#
# Данная архитектура будет очень простой и нужна для того, чтобы установить базовое понимание и получить простенький сабмит на Kaggle
#
# <!-- Здесь вам предлагается дописать сверточную сеть глубины 4/5.  -->
#
# *Описание слоев*:
#
#
#
# 1. размерность входа: 3x224x224
# 2.размерности после слоя:  8x111x111
# 3. 16x54x54
# 4. 32x26x26
# 5. 64x12x12
# 6. выход: 96x5x5

# %%
# Очень простая сеть
class SimpleCnn(nn.Module):
  
    def __init__(self, n_classes):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.batchnorm1 = nn.BatchNorm2d(num_features=8)
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.batchnorm2 = nn.BatchNorm2d(num_features=16)
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.batchnorm3 = nn.BatchNorm2d(num_features=32)
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.batchnorm4 = nn.BatchNorm2d(num_features=64)
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        
        self.out = nn.Linear(96 * 5 * 5, n_classes)
  
  
    def forward(self, x):
        x = self.conv1(x)
        x = self.batchnorm1(x)
        x = self.conv2(x)
        x = self.batchnorm2(x)
        x = self.conv3(x)
        x = self.batchnorm3(x)
        x = self.conv4(x)
        x = self.batchnorm4(x)
        x = self.conv5(x)

        x = x.view(x.size(0), -1)
        logits = self.out(x)
        return logits

# %%
def fit_epoch(model, train_loader, criterion, optimizer):
    running_loss = 0.0
    running_corrects = 0
    processed_data = 0
  
    for inputs, labels in tqdm_notebook(train_loader):
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)
        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        preds = torch.argmax(outputs, 1)
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_data += inputs.size(0)
              
    train_loss = running_loss / processed_data
    train_acc = running_corrects.cpu().numpy() / processed_data
    return train_loss, train_acc

# %%
def eval_epoch(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    running_corrects = 0
    processed_size = 0

    for inputs, labels in val_loader:
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            preds = torch.argmax(outputs, 1)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)
        processed_size += inputs.size(0)
    val_loss = running_loss / processed_size
    val_acc = running_corrects.double() / processed_size
    return val_loss, val_acc

# %%
def eval_classes(model, val_dataset):
    val_loader = DataLoader(val_dataset, batch_size=64)
    model.eval()
    nclasses = 42
    samples = np.zeros(nclasses)
    correct_samples = np.zeros(nclasses)
    for inputs, labels in tqdm_notebook(val_loader):
        inputs = inputs.to(DEVICE)
        labels = labels.to(DEVICE)

        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            preds = torch.argmax(outputs, 1)
        correct = preds == labels.data

        samples[labels.data.cpu()] += 1
        correct_samples[labels.data[correct].cpu()] += 1

    return samples, correct_samples

# %%
def train(train_dataset, val_dataset, model, epochs, batch_size):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} train_loss: {t_loss:0.4f} \
    val_loss {v_loss:0.4f} train_acc {t_acc:0.4f} val_acc {v_acc:0.4f}"

    with tqdm(desc="epoch", total=epochs) as pbar_outer:
        opt = torch.optim.Adam(model.parameters())
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            train_loss, train_acc = fit_epoch(model, train_loader, criterion, opt)
            print("loss", f"{train_loss:.3f}")
            
            val_loss, val_acc = eval_epoch(model, val_loader, criterion)
            history.append((train_loss, train_acc, val_loss, val_acc))
            
            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=train_loss,\
                                           v_loss=val_loss, t_acc=train_acc, v_acc=val_acc))
            
    return history

# %%
def predict(model, test_loader):
    with torch.no_grad():
        logits = []
    
        for inputs in test_loader:
            inputs = inputs.to(DEVICE)
            model.eval()
            outputs = model(inputs).cpu()
            logits.append(outputs)
            
    probs = nn.functional.softmax(torch.cat(logits), dim=-1).numpy()
    return probs

# %%
n_classes = len(np.unique(train_val_labels))
batch_cnn = SimpleCnn(n_classes).to(DEVICE)
print("we will classify :{}".format(n_classes))
print(batch_cnn)
# Out:
# we will classify :42
# SimpleCnn(
#   (conv1): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (batchnorm1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Sequential(
#     (0): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (batchnorm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Sequential(
#     (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (batchnorm3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (batchnorm4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Sequential(
#     (0): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (out): Linear(in_features=2400, out_features=42, bias=True)
# )

# %% [markdown]
# Запустим обучение сети.

# %%
all_dataset = SimpsonsDataset(train_val_files, mode='train')

# %%
train_val_files
# Out:
# [WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0000.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0001.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0002.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0003.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0004.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0005.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0006.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0007.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0008.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0009.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0010.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0011.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0012.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0013.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0014.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0015.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0016.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0017.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0018.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0019.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0020.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0021.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0022.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0023.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0024.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0025.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0026.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0027.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0028.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0029.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0030.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0031.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0032.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0033.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0034.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0035.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0036.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0037.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0038.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0039.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0040.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0041.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0042.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0043.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0044.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0045.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0046.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0047.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0048.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0049.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0050.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0051.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0052.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0053.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0054.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0055.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0056.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0057.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0058.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0059.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0060.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0061.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0062.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0063.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0064.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0065.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0066.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0067.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0068.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0069.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0070.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0071.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0072.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0073.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0074.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0075.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0076.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0077.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0078.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0079.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0080.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0081.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0082.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0083.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0084.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0085.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0086.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0087.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0088.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0089.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0090.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0091.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0092.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0093.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0094.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0095.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0096.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0097.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0098.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0099.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0100.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0101.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0102.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0103.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0104.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0105.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0106.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0107.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0108.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0109.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0110.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0111.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0112.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0113.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0114.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0115.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0116.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0117.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0118.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0119.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0120.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0121.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0122.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0123.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0124.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0125.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0126.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0127.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0128.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0129.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0130.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0131.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0132.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0133.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0134.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0135.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0136.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0137.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0138.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0139.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0140.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0141.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0142.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0143.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0144.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0145.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0146.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0147.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0148.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0149.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0150.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0151.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0152.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0153.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0154.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0155.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0156.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0157.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0158.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0159.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0160.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0161.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0162.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0163.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0164.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0165.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0166.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0167.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0168.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0169.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0170.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0171.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0172.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0173.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0174.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0175.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0176.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0177.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0178.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0179.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0180.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0181.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0182.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0183.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0184.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0185.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0186.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0187.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0188.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0189.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0190.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0191.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0192.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0193.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0194.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0195.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0196.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0197.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0198.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0199.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0200.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0201.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0202.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0203.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0204.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0205.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0206.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0207.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0208.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0209.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0210.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0211.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0212.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0213.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0214.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0215.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0216.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0217.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0218.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0219.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0220.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0221.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0222.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0223.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0224.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0225.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0226.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0227.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0228.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0229.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0230.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0231.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0232.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0233.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0234.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0235.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0236.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0237.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0238.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0239.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0240.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0241.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0242.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0243.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0244.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0245.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0246.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0247.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0248.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0249.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0250.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0251.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0252.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0253.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0254.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0255.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0256.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0257.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0258.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0259.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0260.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0261.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0262.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0263.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0264.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0265.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0266.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0267.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0268.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0269.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0270.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0271.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0272.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0273.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0274.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0275.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0276.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0277.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0278.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0279.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0280.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0281.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0282.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0283.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0284.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0285.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0286.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0287.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0288.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0289.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0290.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0291.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0292.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0293.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0294.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0295.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0296.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0297.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0298.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0299.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0300.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0301.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0302.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0303.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0304.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0305.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0306.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0307.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0308.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0309.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0310.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0311.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0312.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0313.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0314.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0315.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0316.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0317.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0318.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0319.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0320.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0321.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0322.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0323.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0324.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0325.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0326.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0327.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0328.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0329.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0330.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0331.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0332.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0333.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0334.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0335.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0336.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0337.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0338.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0339.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0340.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0341.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0342.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0343.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0344.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0345.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0346.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0347.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0348.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0349.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0350.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0351.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0352.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0353.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0354.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0355.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0356.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0357.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0358.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0359.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0360.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0361.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0362.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0363.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0364.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0365.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0366.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0367.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0368.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0369.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0370.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0371.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0372.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0373.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0374.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0375.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0376.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0377.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0378.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0379.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0380.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0381.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0382.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0383.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0384.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0385.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0386.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0387.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0388.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0389.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0390.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0391.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0392.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0393.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0394.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0395.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0396.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0397.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0398.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0399.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0400.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0401.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0402.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0403.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0404.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0405.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0406.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0407.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0408.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0409.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0410.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0411.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0412.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0413.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0414.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0415.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0416.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0417.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0418.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0419.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0420.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0421.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0422.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0423.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0424.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0425.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0426.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0427.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0428.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0429.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0430.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0431.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0432.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0433.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0434.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0435.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0436.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0437.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0438.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0439.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0440.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0441.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0442.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0443.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0444.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0445.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0446.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0447.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0448.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0449.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0450.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0451.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0452.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0453.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0454.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0455.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0456.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0457.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0458.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0459.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0460.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0461.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0462.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0463.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0464.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0465.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0466.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0467.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0468.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0469.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0470.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0471.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0472.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0473.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0474.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0475.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0476.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0477.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0478.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0479.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0480.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0481.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0482.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0483.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0484.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0485.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0486.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0487.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0488.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0489.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0490.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0491.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0492.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0493.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0494.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0495.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0496.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0497.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0498.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0499.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0500.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0501.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0502.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0503.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0504.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0505.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0506.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0507.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0508.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0509.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0510.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0511.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0512.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0513.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0514.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0515.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0516.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0517.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0518.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0519.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0520.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0521.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0522.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0523.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0524.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0525.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0526.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0527.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0528.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0529.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0530.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0531.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0532.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0533.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0534.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0535.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0536.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0537.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0538.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0539.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0540.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0541.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0542.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0543.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0544.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0545.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0546.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0547.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0548.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0549.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0550.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0551.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0552.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0553.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0554.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0555.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0556.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0557.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0558.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0559.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0560.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0561.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0562.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0563.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0564.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0565.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0566.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0567.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0568.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0569.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0570.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0571.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0572.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0573.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0574.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0575.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0576.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0577.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0578.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0579.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0580.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0581.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0582.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0583.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0584.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0585.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0586.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0587.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0588.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0589.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0590.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0591.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0592.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0593.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0594.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0595.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0596.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0597.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0598.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0599.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0600.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0601.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0602.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0603.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0604.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0605.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0606.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0607.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0608.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0609.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0610.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0611.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0612.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0613.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0614.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0615.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0616.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0617.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0618.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0619.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0620.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0621.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0622.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0623.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0624.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0625.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0626.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0627.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0628.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0629.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0630.jpg'),
# ...
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0785.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0786.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0787.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0788.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0789.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0790.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0791.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0792.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0793.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0794.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0795.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0796.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0797.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0798.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0799.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0800.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0801.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0802.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0803.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0804.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0805.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0806.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0807.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0808.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0809.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0810.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0811.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0812.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0813.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0814.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0815.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0816.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0817.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0818.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0819.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0820.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0821.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0822.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0823.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0824.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0825.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0826.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0827.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0828.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0829.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0830.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0831.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0832.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0833.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0834.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0835.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0836.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0837.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0838.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0839.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0840.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0841.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0842.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0843.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0844.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0845.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0846.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0847.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0848.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0849.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0850.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0851.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0852.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0853.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0854.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0855.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0856.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0857.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0858.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0859.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0860.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0861.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0862.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0863.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0864.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0865.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0866.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0867.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0868.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0869.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0870.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0871.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0872.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0873.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0874.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0875.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0876.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0877.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0878.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0879.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0880.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0881.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0882.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0883.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0884.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0885.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0886.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0887.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0888.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0889.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0890.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0891.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0892.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0893.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0894.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0895.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0896.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0897.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0898.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0899.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0900.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0901.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0902.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0903.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0904.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0905.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0906.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0907.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0908.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0909.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0910.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0911.jpg'),
#  WindowsPath('train/simpsons_dataset/abraham_grampa_simpson/pic_0912.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0000.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0001.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0002.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0003.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0004.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0005.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0006.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0007.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0008.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0009.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0010.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0011.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0012.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0013.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0014.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0015.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0016.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0017.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0018.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0019.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0020.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0021.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0022.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0023.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0024.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0025.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0026.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0027.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0028.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0029.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0030.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0031.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0032.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0033.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0034.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0035.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0036.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0037.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0038.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0039.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0040.jpg'),
#  WindowsPath('train/simpsons_dataset/agnes_skinner/pic_0041.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0000.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0001.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0002.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0003.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0004.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0005.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0006.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0007.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0008.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0009.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0010.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0011.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0012.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0013.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0014.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0015.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0016.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0017.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0018.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0019.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0020.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0021.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0022.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0023.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0024.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0025.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0026.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0027.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0028.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0029.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0030.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0031.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0032.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0033.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0034.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0035.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0036.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0037.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0038.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0039.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0040.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0041.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0042.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0043.jpg'),
#  WindowsPath('train/simpsons_dataset/apu_nahasapeemapetilon/pic_0044.jpg'),
#  ...]

# %%
if val_dataset is None:
    val_dataset = SimpsonsDataset(val_files, mode='val')
val_dataset_trainable = SimpsonsDataset(val_files, mode='train')
train_dataset = SimpsonsDataset(train_files, mode='train')

# %%
DEVICE = torch.device("cuda")
# DEVICE = torch.device("cpu")

# %%
history = train(train_dataset, val_dataset, model=simple_cnn, epochs=1, batch_size=64)
# Out:
# epoch:   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/246 [00:00<?, ?it/s]
# loss 2.156
# epoch: 100%|██████████| 1/1 [06:38<00:00, 398.95s/it]
# Epoch 001 train_loss: 2.1558     val_loss 1.4274 train_acc 0.4043 val_acc 0.6127

# %% [markdown]
# Построим кривые обучения

# %%
def iter_train(train_dataset, val_dataset, model, epochs, batch_size):
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    history = []
    log_template = "\nEpoch {ep:03d} train_loss: {t_loss:0.4f} \
    val_loss {v_loss:0.4f} train_acc {t_acc:0.4f} val_acc {v_acc:0.4f}"

    with tqdm(desc="epoch", total=epochs) as pbar_outer:
        opt = torch.optim.Adam(model.parameters())
        criterion = nn.CrossEntropyLoss()

        for epoch in range(epochs):
            train_loss, train_acc = fit_epoch(model, train_loader, criterion, opt)
            print("loss", f"{train_loss:.3f}")

            val_loss, val_acc = eval_epoch(model, val_loader, criterion)
            yield (train_loss, train_acc, val_loss, val_acc)

            pbar_outer.update(1)
            tqdm.write(log_template.format(ep=epoch+1, t_loss=train_loss,\
                                           v_loss=val_loss, t_acc=train_acc, v_acc=val_acc))

# %%
history = []

# %%
for h in iter_train(train_dataset, val_dataset, model=batch_cnn, epochs=1, batch_size=64):
    history.append(h)
    loss, acc, val_loss, val_acc = zip(*history)
    plt.figure(figsize=(15, 9))
    plt.plot(loss, label="train_loss")
    plt.plot(val_loss, label="val_loss")
    plt.legend(loc='best')
    plt.xlabel("epochs")
    plt.ylabel("loss")
    plt.show()
    # суда можно добавить очистку консоли
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Anaconda\envs\Pytorch\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2956     try:
# -> 2957         fp.seek(0)
#    2958     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'list' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# C:\Users\C6A6~1\AppData\Local\Temp/ipykernel_9884/92946331.py in <module>
# ----> 1 for h in iter_train(train_dataset[:1], val_dataset, model=batch_cnn, epochs=1, batch_size=64):
#       2     history.append(h)
#       3     loss, acc, val_loss, val_acc = zip(*history)
#       4     plt.figure(figsize=(15, 9))
#       5     plt.plot(loss, label="train_loss")
#
# C:\Users\C6A6~1\AppData\Local\Temp/ipykernel_9884/133713517.py in __getitem__(self, index)
#      40             transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#      41         ])
# ---> 42         x = self.load_sample(self.files[index])
#      43         x = self._prepare_sample(x)
#      44         x = np.array(x / 255, dtype='float32')
#
# C:\Users\C6A6~1\AppData\Local\Temp/ipykernel_9884/133713517.py in load_sample(self, file)
#      30
#      31     def load_sample(self, file):
# ---> 32         image = Image.open(file)
#      33         image.load()
#      34         return image
#
# D:\Anaconda\envs\Pytorch\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2957         fp.seek(0)
#    2958     except (AttributeError, io.UnsupportedOperation):
# -> 2959         fp = io.BytesIO(fp.read())
#    2960         exclusive_fp = True
#    2961
#
# AttributeError: 'list' object has no attribute 'read'

# %%
loss, acc, val_loss, val_acc = zip(*history)

# %%
plt.figure(figsize=(15, 9))
plt.plot(acc, label="train_accuracy")
plt.plot([i.cpu() for i in val_acc], label="val_accuracy")
plt.legend(loc='best')
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.show()

# %%
samples, correct_samples = eval_classes(batch_cnn, all_dataset)
# Out:
#   0%|          | 0/328 [00:00<?, ?it/s]

# %%
for a, b in zip(samples, correct_samples/samples):
    print(int(a), b, sep='\t')
# Out:
# 15	1.0
# 1	0.0
# 11	1.0
# 3	0.6666666666666666
# 22	1.0
# 2	0.5
# 20	1.0
# 16	1.0
# 2	0.5
# 8	1.0
# 2	0.0
# 8	1.0
# 1	0.0
# 2	0.0
# 2	1.0
# 37	0.972972972972973
# 8	1.0
# 20	1.0
# 6	0.0
# 1	0.0
# 22	1.0
# 3	0.0
# 21	1.0
# 2	0.5
# 5	0.8
# 18	1.0
# 1	0.0
# 24	0.9583333333333334
# 24	1.0
# 6	1.0
# 2	0.0
# 2	0.5
# 20	1.0
# 2	0.5
# 1	0.0
# 3	0.6666666666666666
# 2	0.5
# 15	0.9333333333333333
# 2	0.0
# 2	1.0
# 1	0.0
# 4	0.0

# %% [markdown]
# ### Ну и что теперь со всем этим делать?

# %% [markdown]
# ![alt text](https://www.indiewire.com/wp-content/uploads/2014/08/the-simpsons.jpg)

# %% [markdown]
# Хорошо бы понять, как сделать сабмит.
# У нас есть сеть и методы eval у нее, которые позволяют перевести сеть в режим предсказания. Стоит понимать, что у нашей модели на последнем слое стоит softmax, которые позволяет получить вектор вероятностей  того, что объект относится к тому или иному классу. Давайте воспользуемся этим.

# %%
def predict_one_sample(model, inputs, device=DEVICE):
    """Предсказание, для одной картинки"""
    with torch.no_grad():
        inputs = inputs.to(device)
        model.eval()
        logit = model(inputs).cpu()
        probs = torch.nn.functional.softmax(logit, dim=-1).numpy()
    return probs

# %%
random_characters = int(np.random.uniform(0,1000))
ex_img, true_label = val_dataset[random_characters]
probs_im = predict_one_sample(batch_cnn, ex_img.unsqueeze(0))

# %%
idxs = list(map(int, np.random.uniform(0,1000, 20)))
imgs = [val_dataset[id][0].unsqueeze(0) for id in idxs]

probs_ims = predict(batch_cnn, imgs)

# %%
label_encoder = pickle.load(open("label_encoder.pkl", 'rb'))

# %%
y_pred = np.argmax(probs_ims,-1)

actual_labels = [val_dataset[id][1] for id in idxs]

preds_class = [label_encoder.classes_[i] for i in y_pred]

# %% [markdown]
# Обратите внимание, что метрика, которую необходимо оптимизировать в конкурсе --- f1-score. Вычислим целевую метрику на валидационной выборке.

# %%
y_pred + np.array(actual_labels, dtype='int64')
# Out:
# array([12,  4,  0,  8, 15, 12, 30,  0, 17, 26, 12, 12, 15,  8, 33,  8, 12,
#        21,  8,  4], dtype=int64)

# %%
from sklearn.metrics import f1_score

# f1_score(actual_labels, preds_class)
f1_score(np.array(actual_labels, dtype='int64'), y_pred, average=None)
# Out:
# array([0.66666667, 0.8       , 0.        , 0.88888889, 0.83333333,
#        0.        , 0.        , 0.        , 0.        ])

# %% [markdown]
# Сделаем классную визуализацию,  чтобы посмотреть насколько сеть уверена в своих ответах. Можете исспользовать это, чтобы отлаживать правильность вывода.

# %%
import matplotlib.patches as patches
from matplotlib.font_manager import FontProperties

fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(12, 12), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    random_characters = int(np.random.uniform(0,1000))
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    
    

    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)
    
    actual_text = "Actual : {}".format(img_label)
            
    fig_x.add_patch(patches.Rectangle((0, 53),86,35,color='white'))
    font0 = FontProperties()
    font = font0.copy()
    font.set_family("fantasy")
    prob_pred = predict_one_sample(batch_cnn, im_val.unsqueeze(0))
    predicted_proba = np.max(prob_pred)*100
    y_pred = np.argmax(prob_pred)
    
    predicted_label = label_encoder.classes_[y_pred]
    predicted_label = predicted_label[:len(predicted_label)//2] + '\n' + predicted_label[len(predicted_label)//2:]
    predicted_text = "{} : {:.0f}%".format(predicted_label,predicted_proba)
            
    fig_x.text(1, 59, predicted_text , horizontalalignment='left', fontproperties=font,
                    verticalalignment='top',fontsize=8, color='black',fontweight='bold')

# %% [markdown]
# Попробуйте найти те классы, которые сеть не смогла расспознать. Изучите данную проблему, это понадобится в дальнейшем.

# %% [markdown]
# ### Submit на Kaggle

# %% [markdown]
# ![alt text](https://i.redd.it/nuaphfioz0211.jpg)

# %%
test_dataset = SimpsonsDataset(test_files, mode="test")
test_loader = DataLoader(test_dataset, shuffle=False, batch_size=64)
probs = predict(batch_cnn, test_loader)


preds = label_encoder.inverse_transform(np.argmax(probs, axis=1))
test_filenames = [path.name for path in test_dataset.files]

# %%
import pandas as pd
# my_submit = pd.read_csv("gdrive/My Drive/simpsons/data/labels.csv")
my_submit = pd.DataFrame({'Id': test_filenames, 'Expected': preds})
my_submit.head()
# Out:
#            Id                Expected
# 0    img0.jpg            nelson_muntz
# 1    img1.jpg            bart_simpson
# 2   img10.jpg            ned_flanders
# 3  img100.jpg            chief_wiggum
# 4  img101.jpg  apu_nahasapeemapetilon

# %%
# TODO : сделайте сабмит (это важно, если Вы не справляетесь, но дошли до этой ячейки, то сообщите в чат и Вам помогут)

# %%
my_submit.to_csv('batch_cnn.csv', index=False)

# %% [markdown]
# ## Приключение?
#
# А теперь самое интересное, мы сделали простенькую сверточную сеть и смогли отправить сабмит, но получившийся скор нас явно не устраивает. Надо с этим что-то сделать.
#
# Несколько срочныйх улучшейни для нашей сети, которые наверняка пришли Вам в голову:
#
#
# *   Учим дольше и изменяем гиперпараметры сети
# *  learning rate, batch size, нормализация картинки и вот это всё
# *   Кто же так строит нейронные сети? А где пулинги и батч нормы? Надо добавлять
# *  Ну разве Адам наше все? [adamW](https://www.fast.ai/2018/07/02/adam-weight-decay/) для практика, [статейка для любителей](https://openreview.net/pdf?id=ryQu7f-RZ) (очень хороший анализ), [наши ](https://github.com/MichaelKonobeev/adashift/) эксперименты для заинтересованных.
#
# * Ну разве это deep learning? Вот ResNet и Inception, которые можно зафайнтьюнить под наши данные, вот это я понимаю (можно и обучить в колабе, а можно и [готовые](https://github.com/Cadene/pretrained-models.pytorch) скачать).
#
# * Данных не очень много, можно их аугументировать и  доучититься на новом датасете ( который уже будет состоять из, как  пример аугументации, перевернутых изображений)
#
# * Стоит подумать об ансамблях
#
#
# Надеюсь, что у Вас получится!
#
# ![alt text](https://pbs.twimg.com/profile_images/798904974986113024/adcQiVdV.jpg)
